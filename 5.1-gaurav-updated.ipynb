# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head(10)
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
# 5  No Urgent Place  Friend(s)   Sunny           80   6PM
# 6  No Urgent Place  Friend(s)   Sunny           55   2PM
# 7  No Urgent Place     Kid(s)   Sunny           80  10AM
# 8  No Urgent Place     Kid(s)   Sunny           80  10AM
# 9  No Urgent Place     Kid(s)   Sunny           80  10AM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
data.dropna()
# Out:
#           destination  passanger weather  temperature  time  \
# 1237  No Urgent Place      Alone   Sunny           55   2PM
# 1238  No Urgent Place  Friend(s)   Sunny           80  10AM
# 1239  No Urgent Place  Friend(s)   Sunny           80  10AM
# 1240  No Urgent Place  Friend(s)   Sunny           80  10AM
# 1241  No Urgent Place  Friend(s)   Sunny           80   2PM
# ...               ...        ...     ...          ...   ...
# 8293             Work      Alone   Rainy           55   7AM
# 8294             Work      Alone   Rainy           55   7AM
# 8295             Work      Alone   Snowy           30   7AM
# 8296             Work      Alone   Snowy           30   7AM
# 8297             Work      Alone   Sunny           80   7AM
#
#                      coupon expiration gender age maritalStatus  ...  \
# 1237        Restaurant(<20)         1d   Male  26        Single  ...
# 1238           Coffee House         2h   Male  26        Single  ...
# ...

# %%
#total number of coupons issued by type
data['coupon'].value_counts(ascending=True).plot(kind = 'bar', title="Total Coupons Issued- by type", grid=True, 
                                    ylabel="Coupon Count", xlabel="Coupon Type", color="Blue", rot=45)
# Out:
# <Axes: title={'center': 'Total Coupons Issued- by type'}, xlabel='Coupon Type', ylabel='Coupon Count'>

# %%
#NOTE- max coupon are issues are of type CoffeeHouse

# %%
#distribution of total coupon accepted per coupon type
sns.countplot(data = data, x = "coupon", hue = 'Y', order=data['coupon'].value_counts(ascending=True).index)
plt.title('Count of Coupons accepted- by coupon type', size = 10)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Restaurant(20-50)'),
#   Text(1, 0, 'Bar'),
#   Text(2, 0, 'Carry out & Take away'),
#   Text(3, 0, 'Restaurant(<20)'),
#   Text(4, 0, 'Coffee House')])

# %%
#NOTE- max coupon accepted are of type Carry out & Take away and Restaurant (< 20)

# %%
#total and percentage of accepted coupons

#create dataframe for Some college - no degree
for coupon_type in ['Restaurant(<20)','Coffee House','Carry out & Take away','Bar','Restaurant(20-50)']:
   grp1 = data[data['coupon'].isin([coupon_type])]
   val= ((grp1['Y'].value_counts()[1])/len(grp1.index))*100
   print("Percentage of coupons accepted with coupon type-",coupon_type,val)
# Out:
# Percentage of coupons accepted with coupon type- Restaurant(<20) 70.71069633883704
# Percentage of coupons accepted with coupon type- Coffee House 49.92492492492492
# Percentage of coupons accepted with coupon type- Carry out & Take away 73.54784788967822
# Percentage of coupons accepted with coupon type- Bar 41.00148735746158
# Percentage of coupons accepted with coupon type- Restaurant(20-50) 44.10187667560322

# %%
#NOTE- coupon with category Carry out & Take away and Restaurant(<20) are accepted with 70%+

# %%
df_accept = data[data['Y']==1]
df_accept
sns.countplot(df_accept, x='coupon', hue='gender')
plt.xticks(rotation = 90)
plt.title('Coupon acceptance by gender')
# Out:
# Text(0.5, 1.0, 'Coupon acceptance by gender')

# %%
#NOTE- Male accepts more Bar coupon while rest are equally accepted.

# %%
#creating groupby dataframe using sum function
accepted_by_education_norm = data['education'].value_counts(normalize=True) * 100
accepted_by_education_norm
# Out:
# education
# Some college - no degree                  34.303059
# Bachelors degree                          34.176916
# Graduate degree (Masters or Doctorate)    14.601072
# Associates degree                          9.090192
# High School Graduate                       7.134973
# Some High School                           0.693787
# Name: proportion, dtype: float64

# %%
data_edu_pie = {'education': ['Some college - no degree', 'Bachelors degree', 'Graduate degree (Masters or Doctorate)', 'Associates degree','High School Graduate','Some High School'],
        'edu_attain': [34.3, 34.2, 14.6, 9.1, 7.1, 0.7]}
data_edu_pie1 = pd.DataFrame(data_edu_pie)
#pie chart visualization of educational attainment of the complete population
plt.pie(data_edu_pie1['edu_attain'], labels=data_edu_pie1['education'], autopct='%1.1f%%')
plt.figure(figsize=(8,8))
plt.show()

# %%
#histogram visualizing coupon utilization (redeemed or not) by educational attainment
sns.countplot(data, x='education', hue='Y',)
plt.xticks(rotation = 90)
plt.title('Coupon Utilization by Education Attainment')
# Out:
# Text(0.5, 1.0, 'Coupon Utilization by Education Attainment')

# %%
#visualization of coupon redemptions by educational attainment of full dataframe
sns.barplot(data = data, x='education', y='Y')
plt.xticks(rotation = 90)
plt.title('Coupon Redemption by Education Attainment')
# Out:
# Text(0.5, 1.0, 'Coupon Redemption by Education Attainment')

# %%
#create dataframe for Some college - no degree
for degree in ['Some college - no degree', 'Bachelors degree', 'Graduate degree (Masters or Doctorate)', 'Associates degree','High School Graduate','Some High School']:
   grp1 = data[data['education'].isin([degree])]
   val= ((grp1['Y'].value_counts()[1])/len(grp1.index))*100
   print("Percentage of coupons accepted with education-",degree,val)
# Out:
# Percentage of coupons accepted with education- Some college - no degree 59.64146173293495
# Percentage of coupons accepted with education- Bachelors degree 55.432525951557096
# Percentage of coupons accepted with education- Graduate degree (Masters or Doctorate) 52.645788336933045
# Percentage of coupons accepted with education- Associates degree 55.33391153512576
# Percentage of coupons accepted with education- High School Graduate 59.22651933701657
# Percentage of coupons accepted with education- Some High School 71.5909090909091

# %%
#Note- even tough 'Some High School' has higher percentage of acceptance but 'Some High School' contributed less to the total population (0.7%)

# %%
sns.histplot(data, x='Bar', kde=True).set(title=' Compare  acceptance rate between Bar visitor',xlabel='Number of visits', ylabel=' Count')

plt.show()

# %%
#create new dataframe with bar data only
dfbar = (data[data['coupon']=='Bar'])
#need to find the number of redeemed coupons and divide by the total number of coupons issued for this population.
percent = ((dfbar['Y'].value_counts()[1])/len(dfbar.index))
print("Percentage of total bar coupon accepted : {:,.1%}".format(percent))
# Out:
# Percentage of total bar coupon accepted : 41.0%

# %%
#create dataframe for 3 or fewer bar visits
dfbar_3few = dfbar[dfbar['Bar'].isin(['never','less1','1~3'])]
#calculate the percent of redeemed
percent_redeemed = dfbar_3few['Y'].value_counts(normalize=True).get(1, 0) * 100

#calculate the percent of not redeemed
percent_not_redeemed = 100 - percent_redeemed
print("Total observations of Bar visitors (3 or Fewer visits/month) accepting coupons: {:.1f}%".format(percent_redeemed))
print("Total observations of Bar visitors (3 or Fewer visits/month) not accepting coupons: {:.1f}%".format(percent_not_redeemed))

#calculate var between not accepting vs accepting
variance_percent = (percent_not_redeemed - percent_redeemed) / percent_redeemed
print("Variance between not accepting and accepting the coupon by Bar visitors (3 or Fewer visits/month): {:.1%}".format(variance_percent))
# Out:
# Total observations of Bar visitors (3 or Fewer visits/month) accepting coupons: 37.1%
# Total observations of Bar visitors (3 or Fewer visits/month) not accepting coupons: 62.9%
# Variance between not accepting and accepting the coupon by Bar visitors (3 or Fewer visits/month): 69.8%

# %%
bar_more1 = ["1~3", "4~8", "gt8"]
gend = ['Male']

# create column for above conditions
#data[((data['Bar'].isin(bar_more1)) & (~data['age'].isin(age_less25)), True, False)]
df2 = data[data['Bar'].isin(bar_more1) & data['gender'].isin(gend)]
male_fewer = df2['Y'].value_counts()[1]/len(df2.index) * 100
print("Total observations of Male Bar visitors (3 or Fewer visits/month) accepting coupons is {:.1f}%".format(male_fewer))
# Out:
# Total observations of Male Bar visitors (3 or Fewer visits/month) accepting coupons is 62.8%

# %%
bar_more1 = ["1~3", "4~8", "gt8"]
age_less25 = ['21', 'below21']

# create column for above conditions
#data[((data['Bar'].isin(bar_more1)) & (~data['age'].isin(age_less25)), True, False)]
df = data[data['Bar'].isin(bar_more1) & ~data['age'].isin(age_less25)]
age25_bar = df['Y'].value_counts()[1]/len(df.index)*100
print("Total observations  vistor with age more than 25 and Bar visitors (3 or Fewer visits/month) accepting coupons is {:.1f}%".format(age25_bar))
# Out:
# Total observations  vistor with age more than 25 and Bar visitors (3 or Fewer visits/month) accepting coupons is 62.2%

# %%
#NOTE- Drivers over 25 years and go to the bar more than once a month are more likely to accept the coupon 62% times

# %%
bar_more1 = ["1~3", "4~8", "gt8"]
occ = ["farming", "fishing"]
passan = ["Kid(s)"]
df1 = data[data['Bar'].isin(bar_more1) & ~data['passanger'].isin(passan) & ~data['occupation'].isin(occ)]
no_kids_occ_fewer_bar= df1['Y'].value_counts()[1]/len(df1.index) * 100
print("Total observations  with no Kids and in not in farming and fishing and Bar visitors (3 or Fewer visits/month) accepting coupons is {:.1f}%".format(no_kids_occ_fewer_bar))
# Out:
# Total observations  with no Kids and in not in farming and fishing and Bar visitors (3 or Fewer visits/month) accepting coupons is 62.3%

# %%
#NOTE- passanger with no kids and not in farming and fishing occuption and go to the bar more than once a month are more likely to accept the coupon 62% times

# %%
passan = ["Friend(s)","Alone"]
age_less25 = ['21', 'below21']
dest = ["No Urgent Place"]
df4 = data[data['age'].isin(age_less25) & data['passanger'].isin(passan) & data['destination'].isin(dest) & data['Y'] == 1]
print("Visitor with coming with Friends and alone with age less than 25 and not going to urgent destination place accepts more Coffee and Resturant coupon")
df4['coupon'].value_counts(normalize=True) * 100
# Out:
# Visitor with coming with Friends and alone with age less than 25 and not going to urgent destination place accepts more Coffee and Resturant coupon
# coupon
# Coffee House             34.352941
# Restaurant(<20)          34.235294
# Carry out & Take away    17.882353
# Bar                      11.294118
# Restaurant(20-50)         2.235294
# Name: proportion, dtype: float64

# %%
#fig.suptitle('Comparing those that accepted Coffee House coupon vs those that did not', size = 25)

df_res = df.query('coupon == "Restaurant(<20)" & Y == 1')
sns.countplot(data = df_res, x = "age", hue = 'gender', order=df_res['age'].value_counts(ascending=True).index)
plt.title('Restaurant(<20) Coupon accepted by age and gender')
plt.show()

# %%
df_res = df.query('coupon == "Restaurant(<20)" & Y == 1')
sns.countplot(data = df_res, x = "age", hue = 'gender', order=df_res['age'].value_counts(ascending=True).index)
plt.title('Restaurant(<20) Coupon accepted by age and gender')
plt.show()

# %%
#sns.barplot(data = data.query('coupon == "Coffee House"'), x = 'weather', y = 'Y')
df_coff = data.query('coupon == "Coffee House" & Y == 1')
sns.countplot(data = df_coff, x = "age", hue = 'weather', order=df_coff['age'].value_counts(ascending=True).index)

plt.title('Coffee house coupon accepted by age w.r.t weather')

plt.show()

# %%
# Out:
# <Axes: xlabel='time', ylabel='Y'>
