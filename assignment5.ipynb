# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plx
import plotly.express as px
import plotly.io as pio 
df = pd.read_csv('5/data/coupons.csv')
df['coupon'].value_counts()
df.sample(5)
df_y1 = df.query('Y == 1')
ax = px.histogram(df_y1, x = 'coupon', color='destination')

# %%
px.histogram(df_y1, x = 'coupon', color='passanger')

# %%
px.histogram(df_y1, x = 'coupon', color='weather')

# %%
px.histogram(df_y1, x = 'coupon', color='gender')

# %%
px.histogram(df_y1, color = 'direction_same', x='coupon')

# %%
px.histogram(df_y1, x = 'coupon', color='destination')

# %%
px.histogram(df_y1, x = 'coupon', color='maritalStatus')

# %%
df_coffee = df.query('coupon == "Coffee House"')
df_filtered = df.loc[df['CoffeeHouse'] != 'never']
px.histogram(df_filtered, x='CoffeeHouse').update_xaxes(categoryorder='total descending',title="Distribution accepting Coffee House coupon w.r.t to CoffeeHouse")

# %%
df.sample(5)
df.groupby(['maritalStatus','Y']).size()
# Out:
# maritalStatus      Y
# Divorced           0     243
#                    1     273
# Married partner    0    2331
#                    1    2769
# Single             0    1873
#                    1    2879
# Unmarried partner  0     959
#                    1    1227
# Widowed            0      68
#                    1      62
# dtype: int64
